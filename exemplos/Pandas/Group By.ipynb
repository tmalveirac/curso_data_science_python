# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('primary_results.csv')

# %%
df
# Out:
#          state state_abbreviation                county        fips  \
# 0      Alabama                 AL               Autauga      1001.0
# 1      Alabama                 AL               Autauga      1001.0
# 2      Alabama                 AL               Baldwin      1003.0
# 3      Alabama                 AL               Baldwin      1003.0
# 4      Alabama                 AL               Barbour      1005.0
# 5      Alabama                 AL               Barbour      1005.0
# 6      Alabama                 AL                  Bibb      1007.0
# 7      Alabama                 AL                  Bibb      1007.0
# 8      Alabama                 AL                Blount      1009.0
# 9      Alabama                 AL                Blount      1009.0
# 10     Alabama                 AL               Bullock      1011.0
# 11     Alabama                 AL               Bullock      1011.0
# 12     Alabama                 AL                Butler      1013.0
# ...

# %%
len(df)
# Out:
# 24611

# %%
df.groupby('candidate')

# %%
df.groupby('candidate').aggregate({'votes': [min, np.mean, max]})
# Out:
#                 votes
#                   min         mean     max
# candidate
#  No Preference      0    23.225071     580
#  Uncommitted        0     0.434343      16
# Ben Carson          0   338.258238    9945
# Bernie Sanders      0  2844.019501  434656
# Carly Fiorina       0   139.366972    3612
# Chris Christie      1   223.422018    7144
# Donald Trump        0  3709.576408  179130
# Hillary Clinton     0  3731.855410  590502
# Jeb Bush            2   609.103226    9575
# John Kasich         0  1160.052705  101217
# Marco Rubio         0  1299.834051  111898
# Martin O'Malley     0     7.595960     152
# Mike Huckabee       2    33.787879     565
# Rand Paul           2    85.646465    1633
# Rick Santorum       0    18.000000     234
# Ted Cruz            0  2120.191299  147721

# %%
df.groupby('candidate').aggregate({'votes': [min, np.mean, max]})
# Out:
#                 votes
#                   min         mean     max
# candidate
#  No Preference      0    23.225071     580
#  Uncommitted        0     0.434343      16
# Ben Carson          0   338.258238    9945
# Bernie Sanders      0  2844.019501  434656
# Carly Fiorina       0   139.366972    3612
# Chris Christie      1   223.422018    7144
# Donald Trump        0  3709.576408  179130
# Hillary Clinton     0  3731.855410  590502
# Jeb Bush            2   609.103226    9575
# John Kasich         0  1160.052705  101217
# Marco Rubio         0  1299.834051  111898
# Martin O'Malley     0     7.595960     152
# Mike Huckabee       2    33.787879     565
# Rand Paul           2    85.646465    1633
# Rick Santorum       0    18.000000     234
# Ted Cruz            0  2120.191299  147721

# %%
df[df['votes'] == 590502]
# Out:
#            state state_abbreviation       county    fips     party  \
# 1386  California                 CA  Los Angeles  6037.0  Democrat
#
#             candidate   votes  fraction_votes
# 1386  Hillary Clinton  590502            0.57

# %%
df.loc[df['votes'] == 590502]
# Out:
#            state state_abbreviation       county    fips     party  \
# 1386  California                 CA  Los Angeles  6037.0  Democrat
#
#             candidate   votes  fraction_votes
# 1386  Hillary Clinton  590502            0.57

# %%
df.groupby('candidate').aggregate({'fraction_votes': [min, np.mean, max]})
# Out:
#                 fraction_votes
#                            min      mean       max
# candidate
#  No Preference           0.000  0.006484  0.030000
#  Uncommitted             0.000  0.000455  0.013000
# Ben Carson               0.000  0.058941  0.415000
# Bernie Sanders           0.000  0.493316  1.000000
# Carly Fiorina            0.000  0.022097  0.117000
# Chris Christie           0.002  0.017773  0.087195
# Donald Trump             0.000  0.466217  0.915000
# Hillary Clinton          0.000  0.461302  1.000000
# Jeb Bush                 0.004  0.044524  0.121000
# John Kasich              0.000  0.122869  0.639000
# Marco Rubio              0.000  0.146959  0.627000
# Martin O'Malley          0.000  0.008303  0.132000
# Mike Huckabee            0.003  0.024192  0.096000
# Rand Paul                0.006  0.034061  0.096000
# Rick Santorum            0.000  0.009960  0.073000
# Ted Cruz                 0.000  0.243453  1.000000

# %%
df[df['fraction_votes'] == 1]
# Out:
#               state state_abbreviation                   county        fips  \
# 475          Alaska                 AK  State House District 12  90200112.0
# 499          Alaska                 AK  State House District 23  90200123.0
# 513          Alaska                 AK   State House District 3  90200103.0
# 517          Alaska                 AK  State House District 31  90200131.0
# 519          Alaska                 AK  State House District 32  90200132.0
# 531          Alaska                 AK  State House District 38  90200138.0
# 537          Alaska                 AK  State House District 40  90200140.0
# 539          Alaska                 AK   State House District 5  90200105.0
# 541          Alaska                 AK   State House District 6  90200106.0
# 545          Alaska                 AK   State House District 8  90200108.0
# 4198          Idaho                 ID                    Clark     16033.0
# ...

# %%
df[(df['fraction_votes'] == 1) & (df['candidate'] == 'Hillary Clinton')]
# Out:
#           state state_abbreviation        county        fips     party  \
# 8142      Maine                 ME         Amity  92300012.0  Democrat
# 8160      Maine                 ME      Atkinson  92300020.0  Democrat
# 8168      Maine                 ME          Avon  92300024.0  Democrat
# 8186      Maine                 ME   Beaver Cove  92300033.0  Democrat
# 8188      Maine                 ME    Beddington  92300034.0  Democrat
# 8292      Maine                 ME       Caswell  92300088.0  Democrat
# 8334      Maine                 ME      Crawford  92300111.0  Democrat
# 8400      Maine                 ME      Edinburg  92300144.0  Democrat
# 8576      Maine                 ME     Lakeville  92300235.0  Democrat
# 8650      Maine                 ME      Masardis  92300274.0  Democrat
# 8700      Maine                 ME        Moscow  92300301.0  Democrat
# 8710      Maine                 ME    New Canada  92300308.0  Democrat
# ...

# %%
def fraction_votes_filter(x):
    return x['votes'].sum() > 1000000
df.groupby('state').filter(fraction_votes_filter)
# Out:
#            state state_abbreviation      county     fips       party  \
# 0        Alabama                 AL     Autauga   1001.0    Democrat
# 1        Alabama                 AL     Autauga   1001.0    Democrat
# 2        Alabama                 AL     Baldwin   1003.0    Democrat
# 3        Alabama                 AL     Baldwin   1003.0    Democrat
# 4        Alabama                 AL     Barbour   1005.0    Democrat
# 5        Alabama                 AL     Barbour   1005.0    Democrat
# 6        Alabama                 AL        Bibb   1007.0    Democrat
# 7        Alabama                 AL        Bibb   1007.0    Democrat
# 8        Alabama                 AL      Blount   1009.0    Democrat
# 9        Alabama                 AL      Blount   1009.0    Democrat
# 10       Alabama                 AL     Bullock   1011.0    Democrat
# 11       Alabama                 AL     Bullock   1011.0    Democrat
# 12       Alabama                 AL      Butler   1013.0    Democrat
# ...

# %%
df[df['state_abbreviation'] == 'AL']['votes'].sum()
# Out:
# 1223959

# %%
df.groupby(['state_abbreviation', 'candidate'])['votes'].sum()
# Out:
# state_abbreviation  candidate
# AK                  Ben Carson            2401
#                     Bernie Sanders         440
#                     Donald Trump          7346
#                     Hillary Clinton         99
#                     John Kasich            892
#                     Marco Rubio           3318
#                     Ted Cruz              7973
# AL                  Ben Carson           87517
#                     Bernie Sanders       76399
#                     Donald Trump        371735
#                     Hillary Clinton     309928
#                     John Kasich          37970
#                     Marco Rubio         159802
#                     Ted Cruz            180608
# AR                  Ben Carson           23173
#                     Bernie Sanders       64868
#                     Donald Trump        133144
#                     Hillary Clinton     144580
#                     John Kasich          15098
# ...

# %%
df['state_abbreviation'].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI',
#        'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI',
#        'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
#        'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT',
#        'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
df[['state_abbreviation', 'candidate']].values
# Out:
# array([['AL', 'Bernie Sanders'],
#        ['AL', 'Hillary Clinton'],
#        ['AL', 'Bernie Sanders'],
#        ...,
#        ['WY', 'John Kasich'],
#        ['WY', 'Marco Rubio'],
#        ['WY', 'Ted Cruz']], dtype=object)

# %%
df.groupby(['state_abbreviation', 'candidate']).describe()
# Out:
#                                      fips                            \
#                                     count          mean         std
# state_abbreviation candidate
# AK                 Ben Carson        40.0  9.020012e+07   11.690452
#                    Bernie Sanders    40.0  9.020012e+07   11.690452
#                    Donald Trump      40.0  9.020012e+07   11.690452
#                    Hillary Clinton   40.0  9.020012e+07   11.690452
#                    John Kasich       40.0  9.020012e+07   11.690452
#                    Marco Rubio       40.0  9.020012e+07   11.690452
#                    Ted Cruz          40.0  9.020012e+07   11.690452
# AL                 Ben Carson        67.0  1.067000e+03   38.970074
#                    Bernie Sanders    67.0  1.067000e+03   38.970074
#                    Donald Trump      67.0  1.067000e+03   38.970074
#                    Hillary Clinton   67.0  1.067000e+03   38.970074
# ...

# %%
df[['state_abbreviation', 'candidate']].groupby(['state_abbreviation', 'candidate']).size()
# Out:
# state_abbreviation  candidate
# AK                  Ben Carson          40
#                     Bernie Sanders      40
#                     Donald Trump        40
#                     Hillary Clinton     40
#                     John Kasich         40
#                     Marco Rubio         40
#                     Ted Cruz            40
# AL                  Ben Carson          67
#                     Bernie Sanders      67
#                     Donald Trump        67
#                     Hillary Clinton     67
#                     John Kasich         67
#                     Marco Rubio         67
#                     Ted Cruz            67
# AR                  Ben Carson          75
#                     Bernie Sanders      75
#                     Donald Trump        75
#                     Hillary Clinton     75
#                     John Kasich         75
#                     Marco Rubio         75
#                     Ted Cruz            75
# ...

# %%
x = df.groupby(['state_abbreviation', 'candidate'])

# %%
for state, cand in x:
    print (state)
    print (cand)
# Out:
# ('AK', 'Ben Carson')
#       state state_abbreviation                   county        fips  \
# 549  Alaska                 AK   State House District 1  90200101.0
# 554  Alaska                 AK  State House District 10  90200110.0
# 559  Alaska                 AK  State House District 11  90200111.0
# 564  Alaska                 AK  State House District 12  90200112.0
# 569  Alaska                 AK  State House District 13  90200113.0
# 574  Alaska                 AK  State House District 14  90200114.0
# 579  Alaska                 AK  State House District 15  90200115.0
# 584  Alaska                 AK  State House District 16  90200116.0
# 589  Alaska                 AK  State House District 17  90200117.0
# 594  Alaska                 AK  State House District 18  90200118.0
# 599  Alaska                 AK  State House District 19  90200119.0
# 604  Alaska                 AK   State House District 2  90200102.0
# ...

# %%
df[['state_abbreviation', 'state']].drop_duplicates()
# Out:
#       state_abbreviation           state
# 0                     AL         Alabama
# 469                   AK          Alaska
# 749                   AZ         Arizona
# 824                   AR        Arkansas
# 1349                  CA      California
# 1639                  CO        Colorado
# 1767                  CT     Connecticut
# 2612                  DE        Delaware
# 2627                  FL         Florida
# 3029                  GA         Georgia
# 4142                  HI          Hawaii
# 4166                  ID           Idaho
# 4430                  IL        Illinois
# 5048                  IN         Indiana
# 5508                  IA            Iowa
# 6993                  KS          Kansas
# 7017                  KY        Kentucky
# 7737                  LA       Louisiana
# 8121                  ME           Maine
# 9115                  MD        Maryland
# 9235                  MA   Massachusetts
# 12043                 MI        Michigan
# ...

# %%
df['state'].drop_duplicates().sort_values().reset_index(drop=True)
# Out:
# 0            Alabama
# 1             Alaska
# 2            Arizona
# 3           Arkansas
# 4         California
# 5           Colorado
# 6        Connecticut
# 7           Delaware
# 8            Florida
# 9            Georgia
# 10            Hawaii
# 11             Idaho
# 12          Illinois
# 13           Indiana
# 14              Iowa
# 15            Kansas
# 16          Kentucky
# 17         Louisiana
# 18             Maine
# 19          Maryland
# 20     Massachusetts
# 21          Michigan
# 22       Mississippi
# 23          Missouri
# 24           Montana
# 25          Nebraska
# 26            Nevada
# 27     New Hampshire
# 28        New Jersey
# 29        New Mexico
# 30          New York
# 31    North Carolina
# 32      North Dakota
# 33              Ohio
# 34          Oklahoma
# 35            Oregon
# 36      Pennsylvania
# 37      Rhode Island
# 38    South Carolina
# 39      South Dakota
# 40         Tennessee
# 41             Texas
# 42              Utah
# ...

# %%
df.groupby(['state_abbreviation', 'candidate'], sort=True).aggregate({'votes':['sum', 'max', 'mean']})
# Out:
#                                       votes
#                                         sum     max          mean
# state_abbreviation candidate
# AK                 Ben Carson          2401     172     60.025000
#                    Bernie Sanders       440      21     11.000000
#                    Donald Trump        7346     464    183.650000
#                    Hillary Clinton       99       6      2.475000
#                    John Kasich          892      56     22.300000
#                    Marco Rubio         3318     215     82.950000
#                    Ted Cruz            7973     455    199.325000
# AL                 Ben Carson         87517    8368   1306.223881
#                    Bernie Sanders     76399   14319   1140.283582
#                    Donald Trump      371735   32853   5548.283582
#                    Hillary Clinton   309928   67357   4625.791045
#                    John Kasich        37970    5711    566.716418
# ...

# %%
df[['state_abbreviation', 'state']].drop_duplicates().sort_values('state')
# Out:
#       state_abbreviation           state
# 0                     AL         Alabama
# 469                   AK          Alaska
# 749                   AZ         Arizona
# 824                   AR        Arkansas
# 1349                  CA      California
# 1639                  CO        Colorado
# 1767                  CT     Connecticut
# 2612                  DE        Delaware
# 2627                  FL         Florida
# 3029                  GA         Georgia
# 4142                  HI          Hawaii
# 4166                  ID           Idaho
# 4430                  IL        Illinois
# 5048                  IN         Indiana
# 5508                  IA            Iowa
# 6993                  KS          Kansas
# 7017                  KY        Kentucky
# 7737                  LA       Louisiana
# 8121                  ME           Maine
# 9115                  MD        Maryland
# 9235                  MA   Massachusetts
# 12043                 MI        Michigan
# ...

# %%
type(df.groupby(['state_abbreviation', 'candidate']).aggregate({'votes':['sum', 'max', 'mean']}))
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby(['state_abbreviation', 'candidate']).aggregate({'votes':['sum', 'max', 'mean']})
# Out:
#                                       votes
#                                         sum     max          mean
# state_abbreviation candidate
# AK                 Ben Carson          2401     172     60.025000
#                    Bernie Sanders       440      21     11.000000
#                    Donald Trump        7346     464    183.650000
#                    Hillary Clinton       99       6      2.475000
#                    John Kasich          892      56     22.300000
#                    Marco Rubio         3318     215     82.950000
#                    Ted Cruz            7973     455    199.325000
# AL                 Ben Carson         87517    8368   1306.223881
#                    Bernie Sanders     76399   14319   1140.283582
#                    Donald Trump      371735   32853   5548.283582
#                    Hillary Clinton   309928   67357   4625.791045
#                    John Kasich        37970    5711    566.716418
# ...

# %%
df.groupby(['state_abbreviation', 'candidate'])['votes'].sum().sort_values(ascending=False)
# Out:
# state_abbreviation  candidate
# CA                  Hillary Clinton    1940580
#                     Bernie Sanders     1502043
# TX                  Ted Cruz           1239370
# CA                  Donald Trump       1174829
# FL                  Hillary Clinton    1097400
#                     Donald Trump       1077221
# NY                  Hillary Clinton    1054083
# IL                  Hillary Clinton    1012175
#                     Bernie Sanders      975659
# OH                  John Kasich         956762
# TX                  Hillary Clinton     935080
# PA                  Hillary Clinton     918689
#                     Donald Trump        892702
# NY                  Bernie Sanders      763469
# TX                  Donald Trump        757618
# OH                  Donald Trump        727585
# PA                  Bernie Sanders      719955
# OH                  Hillary Clinton     679266
# FL                  Marco Rubio         636653
# ...

# %%
from collections import OrderedDict
df.groupby(['state_abbreviation', 'candidate']).aggregate(OrderedDict([('votes', 'sum')]))
# Out:
#                                       votes
# state_abbreviation candidate
# AK                 Ben Carson          2401
#                    Bernie Sanders       440
#                    Donald Trump        7346
#                    Hillary Clinton       99
#                    John Kasich          892
#                    Marco Rubio         3318
#                    Ted Cruz            7973
# AL                 Ben Carson         87517
#                    Bernie Sanders     76399
#                    Donald Trump      371735
#                    Hillary Clinton   309928
#                    John Kasich        37970
#                    Marco Rubio       159802
#                    Ted Cruz          180608
# AR                 Ben Carson         23173
#                    Bernie Sanders     64868
#                    Donald Trump      133144
#                    Hillary Clinton   144580
#                    John Kasich        15098
#                    Marco Rubio       101235
# ...

# %%
df.groupby(['state_abbreviation', 'candidate']).aggregate(OrderedDict([('votes', 'sum')]))
# Out:
#                                       votes
# state_abbreviation candidate
# AK                 Ben Carson          2401
#                    Bernie Sanders       440
#                    Donald Trump        7346
#                    Hillary Clinton       99
#                    John Kasich          892
#                    Marco Rubio         3318
#                    Ted Cruz            7973
# AL                 Ben Carson         87517
#                    Bernie Sanders     76399
#                    Donald Trump      371735
#                    Hillary Clinton   309928
#                    John Kasich        37970
#                    Marco Rubio       159802
#                    Ted Cruz          180608
# AR                 Ben Carson         23173
#                    Bernie Sanders     64868
#                    Donald Trump      133144
#                    Hillary Clinton   144580
#                    John Kasich        15098
#                    Marco Rubio       101235
# ...

# %%
df.groupby(['candidate'])['votes'].sum().sort_values(ascending = False)
# Out:
# candidate
# Hillary Clinton    15692452
# Donald Trump       13302541
# Bernie Sanders     11959102
# Ted Cruz            7603006
# John Kasich         4159949
# Marco Rubio         3321076
# Ben Carson           564553
# Jeb Bush              94411
# Chris Christie        24353
# Carly Fiorina         15191
# Rand Paul              8479
#  No Preference         8152
# Mike Huckabee          3345
# Rick Santorum          1782
# Martin O'Malley         752
#  Uncommitted             43
# Name: votes, dtype: int64

# %%
df.groupby(['candidate'])['votes'].sum().sort_values(ascending = False).to_csv('teste.csv', sep=';', header = True)
